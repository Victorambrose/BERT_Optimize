# %%
import datasets

dataset = datasets.load_dataset("coastalcph/lex_glue", "scotus")

# %% [markdown]
# #### Explore the dataset document length

# %%
highest=0
total_length=0
for idx in range(len(dataset['train'])):
    total_length+=len(dataset['train'][idx]['text'])
    if len(dataset['train'][idx]['text']) > highest:
        highest=len(dataset['train'][idx]['text'])
print (f'The average length of documents in training dataset is {round(total_length/len(dataset['train']))}\nThe lengthy document in the dataset contains {highest} number of tokens')
# Out:
# The average length of documents in training dataset is 35723
# The lengthy document in the dataset contains 562772 number of tokens

# %%
import math
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline
from datasets import DatasetDict

# ----- Step 1: Load the Summarization Model -----
# We use a long-document summarization model that can process lengthy texts.
sum_model_name = "nsi319/legal-led-base-16384"
sum_tokenizer = AutoTokenizer.from_pretrained(sum_model_name)
sum_model = AutoModelForSeq2SeqLM.from_pretrained(sum_model_name)

# Create a summarization pipeline (you can adjust parameters later)
summarizer = pipeline("summarization", model=sum_model, tokenizer=sum_tokenizer, framework="pt")

# ----- Step 2: Define a Function to Summarize a Document -----
def summarize_document(document, summarizer, tokenizer, chunk_size=15000, final_max_length=512):
    """
    Summarize a long document in two stages:
      - If document is longer than chunk_size tokens, split into chunks,
        summarize each chunk, then combine and summarize again.
      - Otherwise, summarize directly.
    
    Args:
        document (str): The full text of the document.
        summarizer: The Hugging Face summarization pipeline.
        tokenizer: The tokenizer corresponding to the summarization model.
        chunk_size (int): Maximum tokens per chunk.
        final_max_length (int): Maximum token length for final summary.
    
    Returns:
        str: Final summary text.
    """
    # Tokenize document without truncation
    tokens = tokenizer.encode(document, truncation=False)
    num_tokens = len(tokens)
    
    # If the document is within chunk_size, summarize directly.
    if num_tokens <= chunk_size:
        summary = summarizer(document, max_length=final_max_length, truncation=True)[0]['summary_text']
        return summary
    else:
        num_chunks = math.ceil(num_tokens / chunk_size)
        chunk_summaries = []
        
        # Process each chunk
        for i in range(num_chunks):
            start = i * chunk_size
            end = min((i + 1) * chunk_size, num_tokens)
            # Decode the token IDs for the current chunk back into text.
            chunk_token_ids = tokens[start:end]
            chunk_text = tokenizer.decode(chunk_token_ids, skip_special_tokens=True)
            # Summarize the chunk (you can adjust max_length for intermediate summaries)
            chunk_summary = summarizer(chunk_text, max_length=final_max_length, truncation=True)[0]['summary_text']
            chunk_summaries.append(chunk_summary)
        
        # Combine all chunk summaries into one text.
        combined_summary_text = " ".join(chunk_summaries)
        # Optionally, if the combined summary is still long, summarize it one more time.
        final_summary = summarizer(combined_summary_text, max_length=final_max_length, truncation=True)[0]['summary_text']
        return final_summary

# ----- Step 3: Apply Summarization to the Training Split Only -----
def summarize_example(example):
    # Assume each example has a "text" field with the long legal document.
    example["text"] = summarize_document(example["text"], summarizer, sum_tokenizer,
                                          chunk_size=15000, final_max_length=400)
    return example

# If your dataset is a Hugging Face DatasetDict (with splits 'train', 'test', 'validation'):
# We only summarize the training set and leave the others as is.
summarized_dataset = DatasetDict({
    "train": dataset["train"].map(summarize_example),
    "test": dataset["test"],
    "validation": dataset["validation"]
})
# Out:
# Device set to use cuda:0
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model
to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4054 to 4096 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3284 to 4096 to be a multiple of `config.attention_window`: 1024
# Your max_length is set to 400, but your input_length is only 383. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=191)
# Input ids are automatically padded from 383 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2598 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 406 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 11754 to 12288 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1974 to 2048 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7622 to 8192 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5658 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5923 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3837 to 4096 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6136 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 975 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7042 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3612 to 4096 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4205 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4372 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5115 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8497 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4099 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3873 to 4096 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 13418 to 14336 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 9945 to 10240 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8962 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2480 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4130 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2774 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2902 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3799 to 4096 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1367 to 2048 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8758 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5593 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6286 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8288 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2628 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 800 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 535 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7215 to 8192 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2369 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6021 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 450 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6421 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10461 to 11264 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4989 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10466 to 11264 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2757 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6558 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 811 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 426 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3972 to 4096 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 13695 to 14336 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4668 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 11040 to 11264 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5082 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2173 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5656 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5723 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4797 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3102 to 4096 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7029 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1345 to 2048 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 790 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2372 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6204 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 896 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1769 to 2048 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7773 to 8192 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 640 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4340 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6264 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3064 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7159 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6566 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 750 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 595 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2498 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3042 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10069 to 10240 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1515 to 2048 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2771 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6712 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8601 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6950 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1593 to 2048 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4763 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2101 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5302 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2438 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 900 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7094 to 7168 to be a multiple of `config.attention_window`: 1024
# ...
# Input ids are automatically padded from 14027 to 14336 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 14353 to 15360 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 13900 to 14336 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10227 to 10240 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4522 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 9215 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1751 to 2048 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2400 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 13102 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 542 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7756 to 8192 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 13916 to 14336 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6726 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 12327 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1374 to 2048 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 12628 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8323 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 9127 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 11523 to 12288 to be a multiple of `config.attention_window`: 1024
# Your max_length is set to 400, but your input_length is only 379. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=189)
# Input ids are automatically padded from 379 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6183 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6647 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 12668 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 11175 to 11264 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8681 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8655 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 9996 to 10240 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10819 to 11264 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5750 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6733 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5129 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7645 to 8192 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4521 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2321 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1955 to 2048 to be a multiple of `config.attention_window`: 1024
# Your max_length is set to 400, but your input_length is only 163. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=81)
# Input ids are automatically padded from 163 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8484 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8188 to 8192 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10046 to 10240 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 12755 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6309 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6055 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 11555 to 12288 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3777 to 4096 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10829 to 11264 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 14512 to 15360 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8082 to 8192 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8530 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8502 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8754 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1564 to 2048 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 9901 to 10240 to be a multiple of `config.attention_window`: 1024
# Your max_length is set to 400, but your input_length is only 309. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=154)
# Your max_length is set to 400, but your input_length is only 125. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Input ids are automatically padded from 125 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 12771 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4176 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5693 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8179 to 8192 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 14740 to 15360 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 14513 to 15360 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10502 to 11264 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7108 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5266 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8460 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 594 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 14977 to 15360 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 11525 to 12288 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 944 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8702 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1110 to 2048 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8264 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1083 to 2048 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 14673 to 15360 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8932 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 9650 to 10240 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7594 to 8192 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5486 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 12332 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 826 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 12497 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10042 to 10240 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2685 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 11922 to 12288 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 480 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4864 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8006 to 8192 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 12825 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 12721 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7056 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 14894 to 15360 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 9180 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6678 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6933 to 7168 to be a multiple of `config.attention_window`: 1024
# Your max_length is set to 400, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Input ids are automatically padded from 68 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 486 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 845 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5047 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3624 to 4096 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2355 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10681 to 11264 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10208 to 10240 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 1443 to 2048 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 11190 to 11264 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 9986 to 10240 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 14055 to 14336 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6788 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3237 to 4096 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 13843 to 14336 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8224 to 9216 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 14183 to 14336 to be a multiple of `config.attention_window`: 1024
# Your max_length is set to 400, but your input_length is only 229. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=114)
# Input ids are automatically padded from 5701 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 9386 to 10240 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7647 to 8192 to be a multiple of `config.attention_window`: 1024
# Your max_length is set to 400, but your input_length is only 58. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Input ids are automatically padded from 440 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10469 to 11264 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 13147 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 12773 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 13955 to 14336 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 3469 to 4096 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 12741 to 13312 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 5796 to 6144 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 752 to 1024 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 4507 to 5120 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 2554 to 3072 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6772 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 8704 to 9216 to be a multiple of `config.attention_window`: 1024
# Your max_length is set to 400, but your input_length is only 106. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Input ids are automatically padded from 14518 to 15360 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6693 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 6161 to 7168 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10423 to 11264 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 10956 to 11264 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 9523 to 10240 to be a multiple of `config.attention_window`: 1024
# Input ids are automatically padded from 7073 to 7168 to be a multiple of `config.attention_window`: 1024

# %%
summarized_dataset.push_to_hub("victorambrose11/summarized_scotus_latest")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/victorambrose11/summarized_scotus_latest/commit/4b3c0124fb3efce22e9a6f6c5c39bac595fe458d', commit_message='Upload dataset', commit_description='', oid='4b3c0124fb3efce22e9a6f6c5c39bac595fe458d', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/victorambrose11/summarized_scotus_latest', endpoint='https://huggingface.co', repo_type='dataset', repo_id='victorambrose11/summarized_scotus_latest'), pr_revision=None, pr_num=None)
